# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
obj = pd.Series([1,5,10, 7], index=["a","b","c","d"])
obj
# Out:
# a     1
# b     5
# c    10
# d     7
# dtype: int64

# %%
10 in obj # Fast
# Out:
# False

# %%
"b" in obj # fast
# Out:
# True

# %%
obj.values
# Out:
# array([ 1,  5, 10,  7])

# %%
7 in obj.values # slow
# Out:
# True

# %%
d = {
    "Name": ["John", "Alice", "Jack", "Rose", "Alex", "David"],
    "Age": [32, 23, 21, 35, 45, 48],
    "City": ["Istanbul", "Paris", "London", "Madrid", "Sao Paulo", "Miami"]
}
d
# Out:
# {'Name': ['John', 'Alice', 'Jack', 'Rose', 'Alex', 'David'],
#  'Age': [32, 23, 21, 35, 45, 48],
#  'City': ['Istanbul', 'Paris', 'London', 'Madrid', 'Sao Paulo', 'Miami']}

# %%
df = pd.DataFrame(d)
df
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.values
# Out:
# array([['John', 32, 'Istanbul'],
#        ['Alice', 23, 'Paris'],
#        ['Jack', 21, 'London'],
#        ['Rose', 35, 'Madrid'],
#        ['Alex', 45, 'Sao Paulo'],
#        ['David', 48, 'Miami']], dtype=object)

# %%
df.shape
# Out:
# (6, 3)

# %%
df
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
df.head() # displays first 5 rows
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo

# %%
df.head(3)
# Out:
#     Name  Age      City
# 0   John   32  Istanbul
# 1  Alice   23     Paris
# 2   Jack   21    London

# %%
df.tail()
# Out:
#     Name  Age       City
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
df.tail(2)
# Out:
#     Name  Age       City
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
df
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
d
# Out:
# {'Name': ['John', 'Alice', 'Jack', 'Rose', 'Alex', 'David'],
#  'Age': [32, 23, 21, 35, 45, 48],
#  'City': ['Istanbul', 'Paris', 'London', 'Madrid', 'Sao Paulo', 'Miami']}

# %%
d["Name"]
# Out:
# ['John', 'Alice', 'Jack', 'Rose', 'Alex', 'David']

# %%
df["Name"]
# Out:
# 0     John
# 1    Alice
# 2     Jack
# 3     Rose
# 4     Alex
# 5    David
# Name: Name, dtype: object

# %%
df
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
df["Age"] # it returns a Series object
# Out:
# 0    32
# 1    23
# 2    21
# 3    35
# 4    45
# 5    48
# Name: Age, dtype: int64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
df[["Name", "Age"]] # it returns a DataFrame
# Out:
#     Name  Age
# 0   John   32
# 1  Alice   23
# 2   Jack   21
# 3   Rose   35
# 4   Alex   45
# 5  David   48

# %%
type(df[["Name", "Age"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["Age"] # series
# Out:
# 0    32
# 1    23
# 2    21
# 3    35
# 4    45
# 5    48
# Name: Age, dtype: int64

# %%
df[["Age"]] # DataFrame
# Out:
#    Age
# 0   32
# 1   23
# 2   21
# 3   35
# 4   45
# 5   48

# %%
df
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
d
# Out:
# {'Name': ['John', 'Alice', 'Jack', 'Rose', 'Alex', 'David'],
#  'Age': [32, 23, 21, 35, 45, 48],
#  'City': ['Istanbul', 'Paris', 'London', 'Madrid', 'Sao Paulo', 'Miami']}

# %%
d["newKey"] = [10, 2,4, 6, 5,7]
d
# Out:
# {'Name': ['John', 'Alice', 'Jack', 'Rose', 'Alex', 'David'],
#  'Age': [32, 23, 21, 35, 45, 48],
#  'City': ['Istanbul', 'Paris', 'London', 'Madrid', 'Sao Paulo', 'Miami'],
#  'newKey': [10, 2, 4, 6, 5, 7]}

# %%
df
# Out:
#     Name  Age       City
# 0   John   32   Istanbul
# 1  Alice   23      Paris
# 2   Jack   21     London
# 3   Rose   35     Madrid
# 4   Alex   45  Sao Paulo
# 5  David   48      Miami

# %%
df["University"] = "Sabanci University"
df
# Out:
#     Name  Age       City          University
# 0   John   32   Istanbul  Sabanci University
# 1  Alice   23      Paris  Sabanci University
# 2   Jack   21     London  Sabanci University
# 3   Rose   35     Madrid  Sabanci University
# 4   Alex   45  Sao Paulo  Sabanci University
# 5  David   48      Miami  Sabanci University

# %%
df["Debt"] = [10, 2, 0, 7, 12, 15]
df
# Out:
#     Name  Age       City          University  Debt
# 0   John   32   Istanbul  Sabanci University    10
# 1  Alice   23      Paris  Sabanci University     2
# 2   Jack   21     London  Sabanci University     0
# 3   Rose   35     Madrid  Sabanci University     7
# 4   Alex   45  Sao Paulo  Sabanci University    12
# 5  David   48      Miami  Sabanci University    15

# %%
df["Debt"] = [10, 20, 0, 17, 12, 15]
df
# Out:
#     Name  Age       City          University  Debt
# 0   John   32   Istanbul  Sabanci University    10
# 1  Alice   23      Paris  Sabanci University    20
# 2   Jack   21     London  Sabanci University     0
# 3   Rose   35     Madrid  Sabanci University    17
# 4   Alex   45  Sao Paulo  Sabanci University    12
# 5  David   48      Miami  Sabanci University    15

# %%
df["Age"]
# Out:
# 0    32
# 1    23
# 2    21
# 3    35
# 4    45
# 5    48
# Name: Age, dtype: int64

# %%
df.Age
# Out:
# 0    32
# 1    23
# 2    21
# 3    35
# 4    45
# 5    48
# Name: Age, dtype: int64

# %%
df.shape
# Out:
# (6, 5)

# %%
df
# Out:
#     Name  Age       City          University  Debt
# 0   John   32   Istanbul  Sabanci University    10
# 1  Alice   23      Paris  Sabanci University    20
# 2   Jack   21     London  Sabanci University     0
# 3   Rose   35     Madrid  Sabanci University    17
# 4   Alex   45  Sao Paulo  Sabanci University    12
# 5  David   48      Miami  Sabanci University    15

# %%
df.drop("University", axis=1) # returns a new DataFrame
# Out:
#     Name  Age       City  Debt
# 0   John   32   Istanbul    10
# 1  Alice   23      Paris    20
# 2   Jack   21     London     0
# 3   Rose   35     Madrid    17
# 4   Alex   45  Sao Paulo    12
# 5  David   48      Miami    15

# %%
df
# Out:
#     Name  Age       City          University  Debt
# 0   John   32   Istanbul  Sabanci University    10
# 1  Alice   23      Paris  Sabanci University    20
# 2   Jack   21     London  Sabanci University     0
# 3   Rose   35     Madrid  Sabanci University    17
# 4   Alex   45  Sao Paulo  Sabanci University    12
# 5  David   48      Miami  Sabanci University    15

# %%
#df = df.drop("University", axis=1)
df.drop("University", axis=1, inplace=True)

# %%
df
# Out:
#     Name  Age       City  Debt
# 0   John   32   Istanbul    10
# 1  Alice   23      Paris    20
# 2   Jack   21     London     0
# 3   Rose   35     Madrid    17
# 4   Alex   45  Sao Paulo    12
# 5  David   48      Miami    15

# %%
df.drop(["Age", "Debt"], axis=1, inplace=True)

# %%
df
# Out:
#     Name       City
# 0   John   Istanbul
# 1  Alice      Paris
# 2   Jack     London
# 3   Rose     Madrid
# 4   Alex  Sao Paulo
# 5  David      Miami

# %%
df.drop([1, 4], axis=0, inplace=True)

# %%
df
# Out:
#     Name      City
# 0   John  Istanbul
# 2   Jack    London
# 3   Rose    Madrid
# 5  David     Miami

# %%
val = df.values
val
# Out:
# array([['John', 'Istanbul'],
#        ['Jack', 'London'],
#        ['Rose', 'Madrid'],
#        ['David', 'Miami']], dtype=object)

# %%
pd.DataFrame(val)
# Out:
#        0         1
# 0   John  Istanbul
# 1   Jack    London
# 2   Rose    Madrid
# 3  David     Miami

# %%
orders = pd.read_table("http://bit.ly/chiporders")
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.shape # returns a tuple object
# Out:
# (4622, 5)

# %%
rowNumber = orders.shape[0]
colNumber = orders.shape[1]

# %%
orders.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
orders.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
orders.describe(include="object")
# Out:
#            item_name choice_description item_price
# count           4622               3376       4622
# unique            50               1043         78
# top     Chicken Bowl        [Diet Coke]     $8.75
# freq             726                134        730

# %%
orders.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
orders.select_dtypes(include="object")
# Out:
#                                   item_name  \
# 0              Chips and Fresh Tomato Salsa
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# ...                                     ...
# 4617                          Steak Burrito
# 4618                          Steak Burrito
# 4619                     Chicken Salad Bowl
# 4620                     Chicken Salad Bowl
# 4621                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...

# %%
orders.select_dtypes(exclude="object")
# Out:
#       order_id  quantity
# 0            1         1
# 1            1         1
# 2            1         1
# 3            1         1
# 4            2         2
# ...        ...       ...
# 4617      1833         1
# 4618      1833         1
# 4619      1834         1
# 4620      1834         1
# 4621      1834         1
#
# [4622 rows x 2 columns]

# %%
users = pd.read_table("http://bit.ly/movieusers", sep="|", header=None)
users.columns = ["ID", "Age", "Gender", "Occ", "Zip Code"] # change the column names
users.head()
# Out:
#    ID  Age Gender         Occ Zip Code
# 0   1   24      M  technician    85711
# 1   2   53      F       other    94043
# 2   3   23      M      writer    32067
# 3   4   24      M  technician    43537
# 4   5   33      F       other    15213

# %%
users = pd.read_table("http://bit.ly/movieusers", sep="|", header=None, 
                      names=["ID", "Age", "Gender", "Occ", "Zip Code"])
users.head()
# Out:
#    ID  Age Gender         Occ Zip Code
# 0   1   24      M  technician    85711
# 1   2   53      F       other    94043
# 2   3   23      M      writer    32067
# 3   4   24      M  technician    43537
# 4   5   33      F       other    15213

# %%
users["Occ"]
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: Occ, Length: 943, dtype: object

# %%
users.Occ
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: Occ, Length: 943, dtype: object

# %%
users["Zip Code"]
# Out:
# 0      85711
# 1      94043
# 2      32067
# 3      43537
# 4      15213
#        ...
# 938    33319
# 939    02215
# 940    97229
# 941    78209
# 942    77841
# Name: Zip Code, Length: 943, dtype: object

# %%
users.describe(include="all")
# Out:
#                 ID         Age Gender      Occ Zip Code
# count   943.000000  943.000000    943      943      943
# unique         NaN         NaN      2       21      795
# top            NaN         NaN      M  student    55414
# freq           NaN         NaN    670      196        9
# mean    472.000000   34.051962    NaN      NaN      NaN
# std     272.364951   12.192740    NaN      NaN      NaN
# min       1.000000    7.000000    NaN      NaN      NaN
# 25%     236.500000   25.000000    NaN      NaN      NaN
# 50%     472.000000   31.000000    NaN      NaN      NaN
# 75%     707.500000   43.000000    NaN      NaN      NaN
# max     943.000000   73.000000    NaN      NaN      NaN

# %%
users.head(3)
# Out:
#    ID  Age Gender         Occ Zip Code
# 0   1   24      M  technician    85711
# 1   2   53      F       other    94043
# 2   3   23      M      writer    32067

# %%
users[:3]
# Out:
#    ID  Age Gender         Occ Zip Code
# 0   1   24      M  technician    85711
# 1   2   53      F       other    94043
# 2   3   23      M      writer    32067

# %%
users[["Age", "Gender", "Occ"]] # returns dataframe
# Out:
#      Age Gender            Occ
# 0     24      M     technician
# 1     53      F          other
# 2     23      M         writer
# 3     24      M     technician
# 4     33      F          other
# ..   ...    ...            ...
# 938   26      F        student
# 939   32      M  administrator
# 940   20      M        student
# 941   48      F      librarian
# 942   22      M        student
#
# [943 rows x 3 columns]

# %%
users[["Age", "Gender", "Occ"]][:4]
# Out:
#    Age Gender         Occ
# 0   24      M  technician
# 1   53      F       other
# 2   23      M      writer
# 3   24      M  technician

# %%
users[:4][["Age", "Gender", "Occ"]] # changed the direction
# Out:
#    Age Gender         Occ
# 0   24      M  technician
# 1   53      F       other
# 2   23      M      writer
# 3   24      M  technician

# %%
movies = pd.read_table("http://bit.ly/imdbratings", sep=",")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies = pd.read_csv("http://bit.ly/imdbratings")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies["duration"].sort_values(ascending=False)
# Out:
# 476    242
# 157    238
# 78     229
# 142    224
# 445    220
#       ...
# 293     68
# 88      68
# 258     67
# 338     66
# 389     64
# Name: duration, Length: 979, dtype: int64

# %%
# find the duration of the longest movie
#movies["duration"].sort_values(ascending=False).index
longestMovieMinute = movies["duration"].sort_values(ascending=False).values[0]
longestMovieMinute
# Out:
# 242

# %%
# find the name of the longest movie

longestMovie = movies.sort_values("duration", ascending=False)["title"].values[0]
longestMovie
# Out:
# 'Hamlet'

# %%
movies.sort_values(["duration", "star_rating"], ascending=[True, False])
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 88           8.4                            The Kid      NOT RATED     Comedy
# 293          8.1                          Duck Soup         PASSED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
movies.shape
# Out:
# (979, 6)

# %%
myList = []
for x in movies["genre"]:
    if x == "Action":
        myList.append(True)
    else:
        myList.append(False)

myList[:10]
# Out:
# [False, False, False, True, False, False, False, False, False, False]

# %%
movies[myList]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
movies[movies["genre"] == "Action"] # filtering in pandas
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
"""
and -> &
or -> |
"""

# %%
movies[(movies["genre"] == "Action") & (movies["duration"] > 180)]
# Out:
#      star_rating                            title content_rating   genre  \
# 385          8.0                        Spartacus          PG-13  Action
# 671          7.7                       Grindhouse              R  Action
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 385       197  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 671       191  [u'Kurt Russell', u'Rose McGowan', u'Danny Tre...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
c1 = movies["genre"] == "Action"
c2 = movies["duration"] > 180
movies[c1 & c2]
# Out:
#      star_rating                            title content_rating   genre  \
# 385          8.0                        Spartacus          PG-13  Action
# 671          7.7                       Grindhouse              R  Action
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 385       197  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 671       191  [u'Kurt Russell', u'Rose McGowan', u'Danny Tre...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
# display the movies longer than 200 minutes
# and (genre is Action or Drama)

movies[(movies["duration"] > 200) & ((movies["genre"] == "Action") | (movies["genre"] == "Drama"))]
# Out:
#      star_rating                            title content_rating   genre  \
# 17           8.7                    Seven Samurai        UNRATED   Drama
# 157          8.2               Gone with the Wind              G   Drama
# 476          7.8                           Hamlet          PG-13   Drama
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
c1 = movies["duration"] > 200
c2 = (movies["genre"] == "Action") | (movies["genre"] == "Drama")

movies[c1 & c2]
# Out:
#      star_rating                            title content_rating   genre  \
# 17           8.7                    Seven Samurai        UNRATED   Drama
# 157          8.2               Gone with the Wind              G   Drama
# 476          7.8                           Hamlet          PG-13   Drama
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
c1 = movies["duration"] > 200
c2 = movies["genre"].isin(["Action", "Drama"])

movies[c1 & c2]
# Out:
#      star_rating                            title content_rating   genre  \
# 17           8.7                    Seven Samurai        UNRATED   Drama
# 157          8.2               Gone with the Wind              G   Drama
# 476          7.8                           Hamlet          PG-13   Drama
# 767          7.6  It's a Mad, Mad, Mad, Mad World       APPROVED  Action
#
#      duration                                        actors_list
# 17        207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 767       205  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
for idx, row in movies.iterrows():
    print(idx, row["star_rating"], row["title"])
    if idx == 3:
        break
# Out:
# 0 9.3 The Shawshank Redemption
# 1 9.2 The Godfather
# 2 9.1 The Godfather: Part II
# 3 9.0 The Dark Knight

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# find the average item_price in the dataset
orders["item_price"].str.replace("$", "").astype(float).mean()
# Out:
# 7.464335785374297

# %%
# find the average item_price in the dataset
orders["item_price"].str.slice(1).astype(float).mean()
# Out:
# 7.464335785374297

# %%
# calculate the average item price of the items
# whose item name is Chicken Bowl

#orders[orders["item_name"] == "Chicken Bowl"]["item_price"].str.replace("$", "").astype(float).mean()
temp_df = orders[orders["item_name"] == "Chicken Bowl"]
temp_df["item_price"].str.slice(1).astype(float).mean()
# Out:
# 10.113953168044079

# %%
# find the average price of items whose item name contains chicken

chicken_df = orders[orders["item_name"].str.lower().str.contains("chicken")]
chicken_df["item_price"].str.slice(1).astype(float).mean()
# Out:
# 10.133724358974359

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# find the average beer cons in Europe
drinks[drinks["continent"] == "Europe"]["beer_servings"].mean()
# Out:
# 193.77777777777777

# %%
drinks["continent"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
# repeat it for all continents
for cont in drinks["continent"].unique():
    res = drinks[drinks["continent"] == cont]["beer_servings"].mean()
    print(cont, res)
# Out:
# Asia 37.04545454545455
# Europe 193.77777777777777
# Africa 61.471698113207545
# North America 145.43478260869566
# South America 175.08333333333334
# Oceania 89.6875

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.groupby("continent").max()
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# continent
# Africa               Zimbabwe            376              152            233
# Asia                    Yemen            247              326            123
# Europe         United Kingdom            361              373            370
# North America             USA            285              438            100
# Oceania               Vanuatu            306              254            212
# South America       Venezuela            333              302            221
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                  9.1
# Asia                                   11.5
# Europe                                 14.4
# North America                          11.9
# Oceania                                10.4
# South America                           8.3

# %%
drinks.groupby("continent").mean(numeric_only=True)
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
drinks.groupby("continent").mean(numeric_only=True)["beer_servings"]
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby("continent")["beer_servings"].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
# repeat it for all continents
for cont in drinks["continent"].unique():
    res = drinks[drinks["continent"] == cont]["beer_servings"].mean()
    print(cont, res)
# Out:
# Asia 37.04545454545455
# Europe 193.77777777777777
# Africa 61.471698113207545
# North America 145.43478260869566
# South America 175.08333333333334
# Oceania 89.6875

# %%
drinks.groupby("continent")["beer_servings"].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby("continent")["beer_servings"].mean().index
# Out:
# Index(['Africa', 'Asia', 'Europe', 'North America', 'Oceania',
#        'South America'],
#       dtype='object', name='continent')

# %%
drinks.groupby("continent")["beer_servings"].mean().values
# Out:
# array([ 61.47169811,  37.04545455, 193.77777778, 145.43478261,
#         89.6875    , 175.08333333])

# %%
drinks.groupby("continent")["beer_servings"].mean().plot()
# Out:
# <Axes: xlabel='continent'>

# %%
drinks.groupby("continent")["beer_servings"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %%
drinks.groupby("continent").mean(numeric_only=True).plot(kind="bar", figsize=(15, 10))
# Out:
# <Axes: xlabel='continent'>

# %%
# find the country that consumes the most beer in Europe

drinks[drinks["continent"] == "Europe"].sort_values("beer_servings", ascending=False)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 45       Czech Republic            361              170            134
# 65              Germany            346              117            175
# 135              Poland            343              215             56
# 98            Lithuania            343              244             56
# 81              Ireland            313              118            165
# 140             Romania            297              122            167
# 16              Belgium            295               84            212
# 160               Spain            284              157            112
# 151              Serbia            283              131            127
# 93               Latvia            281              216             62
# 9               Austria            279               75            191
# 156            Slovenia            270               51            276
# ...

# %%
# find the country that consumes the most beer in Europe

drinks[drinks["continent"] == "Europe"].sort_values("beer_servings", ascending=False)["country"].values[0]
# Out:
# 'Czech Republic'

# %%
# find the country that consumes the most wine in Europe

drinks[drinks["continent"] == "Europe"].sort_values("wine_servings", ascending=False)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 61               France            127              151            370
# 136            Portugal            194               67            339
# 3               Andorra            245              138            312
# 166         Switzerland            185              100            280
# 48              Denmark            224               81            278
# 156            Slovenia            270               51            276
# 99           Luxembourg            236              133            271
# 42              Croatia            230               87            254
# 83                Italy             85               42            237
# 67               Greece            133              112            218
# 16              Belgium            295               84            212
# 182      United Kingdom            219              126            195
# ...
